# %%
from sklearn import datasets
datasets.make_*?
datasets.make_biclusters
import sklearn.datasets as d
import numpy as np
# Out:
# datasets.make_biclusters
# datasets.make_blobs
# datasets.make_checkerboard
# datasets.make_circles
# datasets.make_classification
# datasets.make_friedman1
# datasets.make_friedman2
# datasets.make_friedman3
# datasets.make_gaussian_quantiles
# datasets.make_hastie_10_2
# datasets.make_low_rank_matrix
# datasets.make_moons
# datasets.make_multilabel_classification
# datasets.make_regression
# datasets.make_s_curve
# datasets.make_sparse_coded_signal
# datasets.make_sparse_spd_matrix
# datasets.make_sparse_uncorrelated
# datasets.make_spd_matrix
# datasets.make_swiss_roll

# %%
# Por defecto, esto generara una tupla con 100 x 100 matrices de ejemplo con 100 caracteristicas. 
reg_data = d.make_regression()
# Out:
# (array([[-0.59145053,  0.53927291, -0.83596642, ...,  2.12292186,
#           0.48605886,  0.54285593],
#         [ 1.55989136, -0.85903937,  0.09694476, ..., -1.3147461 ,
#           0.49826935,  1.26107816],
#         [ 2.03975123, -0.42242223, -0.57860585, ..., -0.13794906,
#          -1.73840575,  0.05316246],
#         ...,
#         [-0.03042757,  2.05368021,  0.15110203, ..., -2.51843171,
#          -1.35791161,  0.19430159],
#         [-0.22509515,  0.18297966,  1.0783217 , ..., -1.01924775,
#          -1.64389805,  0.02726525],
#         [ 0.85721696, -0.27451817,  1.29010949, ..., -0.57703534,
#          -0.3376382 , -0.79922955]]),
#  array([ -60.42400681,   73.44384901,  314.99430991, -237.64029412,
#         -111.26458063, -410.31446531, -206.60702285, -183.36445968,
#           65.71968037,  186.80137339,   17.35440374,  116.60280016,
#         -250.28275953,   31.84907725, -351.75372292,   83.01029917,
# ...

# %%
# Este código está creando un conjunto de datos de clasificación desequilibrado (unbalanced dataset) 
# utilizando make_classification de sklearn.datasets, y luego cuenta cuántas muestras hay 
# en cada clase usando np.bincount

classification_set = d.make_classification(weights=[0.1])
np.bincount(classification_set[1])
# Out:
# array([10, 90], dtype=int64)

# %%
# Este fragmento de código está mostrando cómo crear un dataset sintético para pruebas de clustering, 
# particularmente con un formato ideal para k-means. 

blobs_data, blobs_target = d.make_blobs()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline  # Solo necesario en Jupyter Notebooks para mostrar los gráficos dentro del notebook

plt.scatter(blobs_data[:,0], blobs_data[:,1], c=blobs_target)
